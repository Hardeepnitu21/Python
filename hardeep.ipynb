# %%
a=50
b=70
c=a*b
print (c)
# Out:
# 3500

# %%
s=30
s+=30   # s=s+30
print(s)
# Out:
# 60

# %%
num1=int(input("Enter the first number:"))
if num1 % 2==0:
  print("even")
else:
  print("odd")
# Out:
# Enter the first number:3
# odd

# %%
a= 76.6
print(type(a))

# %%
a =  76.6
print(type(a))
# Out:
# <class 'float'>

# %%
numa="123"
print(type(numa))
numb=67
numb=str(numb)
print(type(numa))
print(numa+numb)
# Out:
# <class 'str'>
# <class 'str'>
# 12367

# %%
num1=35
num2="123"

# %%
Functions
-built in
-user defined

# %%
def my_fun():  #initialiation
  print("I have made my function")
  # no output as fxn is declared not calling

my_fun()
# Out:
# I have made my function

# %%
def demo(a,b):
  a=int(input("Enter the first number:"))
  b=int(input("Enter the second number:"))
  print(a*b)
demo(a,b)
# Out:
# Enter the first number:23
# Enter the second number:63
# 1449

# %%
def demo(a,b):

  print(a*b)
  a=int(input("Enter the first number:"))
  b=int(input("Enter the second number:"))
demo(a,b)
# Out:
# 5362.0
# Enter the first number:23
# Enter the second number:63

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %% [markdown]
# **to upload xls file**
# df=pd.read

# %% [markdown]
# import numpy as np  **#numerical pytthon libraries**
# arr=np.array([1,2,3,4,5])
# print(arr)
# print(type(arr))
#
# print(arr[1:5])
# **#slicing(star index: end index)** to obtain small part from list
#
# **SHAPE**
#
#
# print(arr.shape)  # dimensions of array
# **reshape**
#
# **ITERATING (LOOPS)**
# for x in arr:
# print (x)
#
# **concatenate**

# %% [markdown]
# **PANDAS**  remove extra or give average or data cleaning
# import pandas as pd

# %% [markdown]
# visualisaion libraries  #graph or plot
# import seaborn as sns
# # reading data set
# df=sns.load_dataset('tips')
# sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')

# %%
import seaborn as sns
# reading data set
df=sns.load_dataset('diamonds')
df
#.barplot(x='day', y='total_bill', data=df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# **search for seaborn data set in google
# define label for axis**
# matplotlib.plot
#
# box plot
# (to interpret min, max, pecentile etc)

# %%
"P Y T H O N"
"0 1 2 3 4 5"
FOR SLICING[2:4] FOR T and H
